# %% [markdown]
# # Music recommender system

# %% [markdown]
# ### Importing required libraries

# %%
import numpy as np
import pandas as pd

# %%
from typing import List, Dict

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ### Dataset

# %%
songs = pd.read_csv('songdata.csv')

# %%
songs.head()
# Out:
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
# 3   ABBA                   Bang                  /a/abba/bang_20598415.html
# 4   ABBA       Bang-A-Boomerang      /a/abba/bang+a+boomerang_20002668.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \nAnd...
# 1  Take it easy with me, please  \nTouch me gentl...
# 2  I'll never know why I had to go  \nWhy I had t...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %% [markdown]
# Dataset being Big , we have taken random 1000 songs

# %%
songs = songs.sample(n=1000).drop('link', axis=1).reset_index(drop=True)

# %%
songs['text'] = songs['text'].str.replace(r'\n', '')

# %%
tfidf = TfidfVectorizer(analyzer='word', stop_words='english')

# %%
lyrics_matrix = tfidf.fit_transform(songs['text'])

# %%
cosine_similarities = cosine_similarity(lyrics_matrix)

# %% [markdown]
# Once we get the similarities, we'll store in a dictionary the names of the 50  most similar songs for each song in our dataset.

# %%
similarities = {}

# %%
for i in range(len(cosine_similarities)):
    similar_indices = cosine_similarities[i].argsort()[:-50:-1] 

    similarities[songs['song'].iloc[i]] = [(cosine_similarities[i][x], songs['song'][x], songs['artist'][x]) for x in similar_indices][1:]

# %% [markdown]
# We can use that similarity scores to access the most similar items and give a recommendation.

# %%
class ContentBasedRecommender:
    def __init__(self, matrix):
        self.matrix_similar = matrix

    def _print_message(self, song, recom_song):
        rec_items = len(recom_song)
        
        print(f'The {rec_items} recommended songs for {song} are:')
        for i in range(rec_items):
            print(f"Number {i+1}:")
            print(f"{recom_song[i][1]} by {recom_song[i][2]} with {round(recom_song[i][0], 3)} similarity score") 
            print("--------------------")
        
    def recommend(self, recommendation):
        song = recommendation['song']
        number_songs = recommendation['number_songs']
        recom_song = self.matrix_similar[song][:number_songs]
        self._print_message(song=song, recom_song=recom_song)

# %%
recommedations = ContentBasedRecommender(similarities)

# %%
songs
# Out:
#                  artist                            song  \
# 0             Hank Snow           Chattanooga Choo Choo
# 1           John Denver                   My Sweet Lady
# 2            Etta James                  The Man I love
# 3              Kid Rock        The Prodigal Son Returns
# 4       David Allan Coe              Call Me The Breeze
# 5             Radiohead              Sit Down, Stand Up
# 6        Billie Holiday           It's Easy To Remember
# 7          Kenny Rogers                  In Our Old Age
# 8       Christmas Songs   It Came Upon A Midnight Clear
# 9        Linda Ronstadt       I Fall In Love Too Easily
# 10         James Taylor                        Only One
# 11           Jason Mraz             On Love, In Sadness
# 12           The Weeknd                        Thursday
# 13                 Korn            Lullaby For A Sadist
# 14          The Killers                    Read My Mind
# 15                 Devo                   Golden Energy
# 16        Yolanda Adams              Just A Prayer Away
# 17           Uriah Heep                   Free 'n' Easy
# 18       George Michael                       Soul Free
# 19        Nat King Cole              Let's Fall In Love
# 20     Barbra Streisand          Everything Must Change
# 21     Vanessa Williams              Colors Of The Wind
# 20   Everything must change  Nothing stays the same...
# 21   You think you own whatever land you land on  T...
# 22   When Her Eyes Are On The Child  Words by Ray B...
# 23   I shake and I shudder and I shiver  In my bath...
# 24   Well, I knocked down on your door, baby,  To s...
# 25   Hey!! Come on now, everyone sit down and shut ...
# 26   It's time for truth the barker said and poured...
# 27   Slow talkin', the line you're walkin'  Look li...
# 28   And when the sunshine showed  Her face I felt ...
# 29   Maria has a music box she winds up most every ...
# ..                                                 ...
# 970  I found the pieces in my hand  They were alway...
# 971  I come from just the other side of nowhere  To...
# 972  I'm through the place where I don't know my na...
# 973  The queen of the Nile  She laid on her throne ...
# 974  Sup up your beer and collect your fags,  There...
# 975  Soft parachutes  Fourth of July  Villages burn...
# 976  We'd like to welcome y'all to the fabulous Car...
# 977  It's been a while, I haven't seen you for at l...
# 978  Santa Maria choose your children  Santa Maria ...
# 979  Woke up on a bus and heard the driver say  Fri...
# 980  Between every man there is a division  Nobody ...
# 981  Red brick dream  Windows scream  As the rustin...
# 982  [VERSE 1]  Think about it  There must be highe...
# 983  You're so bad, you're so bad, you're so  You'r...
# 984  Having a good time, baby  You're having a ball...
# 985  Well, I got a woman, way over town  She's good...
# 986  I once had a girl, or should I say, she once h...
# 987  Singing for the lonely  You're not the only on...
# 988  One look in your innocent eyes  And I knew you...
# 989  Oh Lord, Oh Lord we lift you ooh we lift you u...
# 990  Everybody knows that I'm just a Joe that likes...
# 991  Why can't it stay like this forever?  Why does...
# 992  I stayed in town for a while  Watching cars pa...
# 993  There ain't nothing in the bottom of your glas...
# 994  I want to say yes to what you say  If there's ...
# 995  No, you couldn't call Jesse a babe in the wood...
# 996  You sit there in your heartache  Waiting on so...
# 997  The man is crying  Take me to a different plac...
# 998  I am terrified of all things.  Frightened of t...
# 999  Get down make love  Get down make love  Get do...
#
# [1000 rows x 3 columns]

# %%
song_name=input("Choose any Song from the list: " )
song_number=int(input("Choose number of songs you want as recommended "))
# Out:
# Choose any Song from the list: Get Down Make Love
# Choose number of songs you want as recommended 5

# %%
recommendation = {
    "song": song_name,
    "number_songs": song_number 
}

# %%
recommedations.recommend(recommendation)
# Out:
# The 5 recommended songs for Get Down Make Love are:
# Number 1:
# It's So Cool by Madonna with 0.464 similarity score
# --------------------
# Number 2:
# Move Me by Cher with 0.394 similarity score
# --------------------
# Number 3:
# Only Girl by Ellie Goulding with 0.312 similarity score
# --------------------
# Number 4:
# Bad Time by Grand Funk Railroad with 0.301 similarity score
# --------------------
# Number 5:
# Nights In White Satin by Moody Blues with 0.273 similarity score
# --------------------
